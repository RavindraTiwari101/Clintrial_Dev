-- %%
USE CATALOG clintrail_dev;
	USE SCHEMA clintrail_bronze;

	-- 1. DM  Demographics
	CREATE TABLE IF NOT EXISTS clintrail_dev.clintrail_bronze.dm (
		STUDYID STRING,
		DOMAIN STRING,
		USUBJID STRING,
		SUBJID STRING,
		SITEID STRING,
		COUNTRY STRING,
		RFICDTC DATE,
		RFSTDTC DATE,
		RFENDTC DATE,
		AGE INT,
		AGEU STRING,
		SEX STRING,
		RACE STRING,
		ETHNIC STRING,
		ARM STRING,
		ARMCD STRING,
		ACTARM STRING,
		ACTARMCD STRING,
		MODIFIED_TS TIMESTAMP,
		bronze_ingest_date DATE
	)
	USING DELTA
	LOCATION 'abfss://bronze@stclintrialdev1.dfs.core.windows.net/dm'
	COMMENT 'bronze: raw DM (Demographics). Append-only history. Delta feed.';

	-- 2. SV  Subject Visits
	CREATE TABLE IF NOT EXISTS clintrail_dev.clintrail_bronze.sv (
		STUDYID STRING,
		DOMAIN STRING,
		USUBJID STRING,
		VISITNUM DECIMAL(5,1),
		VISIT STRING,
		SVSTDTC DATE,
		SVENDTC DATE,
		PROTOCOLDEV STRING,
		MODIFIED_TS TIMESTAMP,
		bronze_ingest_date DATE
	)
	USING DELTA
	LOCATION 'abfss://bronze@stclintrialdev1.dfs.core.windows.net/sv'
	COMMENT 'bronze: raw SV (Subject Visits). Append-only history. Delta feed.';

	-- 3. VS  Vital Signs
	CREATE TABLE IF NOT EXISTS clintrail_dev.clintrail_bronze.vs (
		STUDYID STRING,
		DOMAIN STRING,
		USUBJID STRING,
		VSSEQ INT,
		VSTESTCD STRING,
		VSTEST STRING,
		VSORRES DECIMAL(12,3),
		VSORRESU STRING,
		VISITNUM DECIMAL(5,1),
		VISIT STRING,
		VSDTC DATE,
		MODIFIED_TS TIMESTAMP,
		bronze_ingest_date DATE
	)
	USING DELTA
	LOCATION 'abfss://bronze@stclintrialdev1.dfs.core.windows.net/vs'
	COMMENT 'bronze: raw VS (Vital Signs). Append-only history. Delta feed.';

	-- 4. LB  Laboratory
	CREATE TABLE IF NOT EXISTS clintrail_dev.clintrail_bronze.lb (
		STUDYID STRING,
		DOMAIN STRING,
		USUBJID STRING,
		LBSEQ INT,
		LBTESTCD STRING,
		LBTEST STRING,
		LBCAT STRING,
		LBORRES DECIMAL(12,3),
		LBORRESU STRING,
		LBORNRLO DECIMAL(12,3),
		LBORNRHI DECIMAL(12,3),
		LBNRIND STRING,
		VISITNUM DECIMAL(5,1),
		VISIT STRING,
		LBDTC DATE,
		MODIFIED_TS TIMESTAMP,
		bronze_ingest_date DATE
	)
	USING DELTA
	LOCATION 'abfss://bronze@stclintrialdev1.dfs.core.windows.net/lb'
	COMMENT 'bronze: raw LB (Laboratory). Append-only history. Delta feed.';

	-- 5. EG  ECG
	CREATE TABLE IF NOT EXISTS clintrail_dev.clintrail_bronze.eg (
		STUDYID STRING,
		DOMAIN STRING,
		USUBJID STRING,
		EGSEQ INT,
		EGTESTCD STRING,
		EGTEST STRING,
		EGORRES DECIMAL(12,3),
		EGORRESU STRING,
		VISITNUM DECIMAL(5,1),
		VISIT STRING,
		EGDTC DATE,
		MODIFIED_TS TIMESTAMP,
		bronze_ingest_date DATE
	)
	USING DELTA
	LOCATION 'abfss://bronze@stclintrialdev1.dfs.core.windows.net/eg'
	COMMENT 'bronze: raw EG (ECG). Append-only history. Delta feed.';

	-- 6. EC  Exposure as Collected
	
	CREATE TABLE IF NOT EXISTS clintrail_dev.clintrail_bronze.ec (
		STUDYID STRING,
		DOMAIN STRING,
		USUBJID STRING,
		ECSEQ INT,
		ECTRT STRING,
		ECDOSE DECIMAL(10,2),
		ECDOSU STRING,
		ECROUTE STRING,
		ECSTDTC DATE,
		ECENDTC DATE,
		VISITNUM DECIMAL(5,1),
		VISIT STRING,
		MODIFIED_TS TIMESTAMP,
		bronze_ingest_date DATE
	)
	USING DELTA
	LOCATION 'abfss://bronze@stclintrialdev1.dfs.core.windows.net/ec'
	COMMENT 'bronze: raw EC (Exposure as Collected). Append-only history. Delta feed.';

	-- 7. CM  Concomitant Medications
	CREATE TABLE IF NOT EXISTS clintrail_dev.clintrail_bronze.cm (
		STUDYID STRING,
		DOMAIN STRING,
		USUBJID STRING,
		CMSEQ INT,
		CMTRT STRING,
		CMDECOD STRING,
		CMDOSE DECIMAL(10,2),
		CMDOSU STRING,
		CMROUTE STRING,
		CMSTDTC DATE,
		CMENDTC DATE,
		CMINDC STRING,
		MODIFIED_TS TIMESTAMP,
		bronze_ingest_date DATE
	)
	USING DELTA
	LOCATION 'abfss://bronze@stclintrialdev1.dfs.core.windows.net/cm'
	COMMENT 'bronze: raw CM (Concomitant Medications). Append-only history. Delta feed.';

	-- 8. DS  Disposition
	CREATE TABLE IF NOT EXISTS clintrail_dev.clintrail_bronze.ds (
		STUDYID STRING,
		DOMAIN STRING,
		USUBJID STRING,
		DSSEQ INT,
		DSTERM STRING,
		DSDECOD STRING,
		DSCAT STRING,
		DSSTDTC DATE,
		MODIFIED_TS TIMESTAMP,
		bronze_ingest_date DATE
	)
	USING DELTA
	LOCATION 'abfss://bronze@stclintrialdev1.dfs.core.windows.net/ds'
	COMMENT 'bronze: raw DS (Disposition). Append-only history of daily FULL snapshots.';


-- 9. TA  Trial Arms
	CREATE TABLE IF NOT EXISTS clintrail_dev.clintrail_bronze.ta (
		STUDYID STRING,
		DOMAIN STRING,
		ARMCD STRING,
		ARM STRING,
		TAETORD INT,
		ETCD STRING,
		ELEMENT STRING,
		MODIFIED_TS TIMESTAMP,
		bronze_ingest_date DATE
	)
	USING DELTA
	LOCATION 'abfss://bronze@stclintrialdev1.dfs.core.windows.net/ta'
	COMMENT 'bronze: raw TA (Trial Arms). Append-only history of daily FULL snapshots.';

	-- 10.TS  Trial Summary
	CREATE TABLE IF NOT EXISTS clintrail_dev.clintrail_bronze.ts (
		STUDYID STRING,
		DOMAIN STRING,
		TSPARMCD STRING,
		TSPARM STRING,
		TSVAL STRING,
		MODIFIED_TS TIMESTAMP,
		bronze_ingest_date DATE
	)
	USING DELTA
	LOCATION 'abfss://bronze@stclintrialdev1.dfs.core.windows.net/ts'
	COMMENT 'bronze: raw TS (Trial Summary). Append-only history of daily FULL snapshots.';

	-- Verify
	SHOW TABLES IN clintrail_dev.clintrail_bronze;
	DESCRIBE TABLE EXTENDED clintrail_dev.clintrail_bronze.ec;
	select * from clintrail_dev.clintrail_bronze.ec;
	--	drop table clintrail_dev.clintrail_bronze.dm;
	--	drop table clintrail_dev.clintrail_bronze.sv;
	--	drop table clintrail_dev.clintrail_bronze.vs;
	--	drop table clintrail_dev.clintrail_bronze.lb;
	--	drop table clintrail_dev.clintrail_bronze.eg;
	--	drop table clintrail_dev.clintrail_bronze.ec;
	--	drop table clintrail_dev.clintrail_bronze.cm;
	--	drop table clintrail_dev.clintrail_bronze.ds;
	--	drop table clintrail_dev.clintrail_bronze.ta;
	--	drop table clintrail_dev.clintrail_bronze.ts;
